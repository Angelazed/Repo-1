# %% [markdown]
# # START

# %%
# Check the Python version of the editor:
import sys
print(sys.version)
# Out:
# 3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]

# %%
if 5>2:
    print("Five is greater than two!")  #we don't put numbers inside double quotes

# By default, the print() function ends with a new line. If you want to print multiple words on the same line, you can use the end parameter:
print("Hello World!", end=" ")
print("I will print on the same line.") #Note that we add a space after end=" " for better readability.

print(2 * 5)

print("I am", 35, "years old.")

#---- python comments

#Python allows you to assign values to multiple variables in one line:
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)

#If you have a collection of values in a list, tuple etc. Python allows you to extract the values into variables. This is called unpacking:
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# Five is greater than two!
# Hello World! I will print on the same line.
# 10
# I am 35 years old.

# %% [markdown]
# # Python Data Types

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex, written with a "j" as the imaginary part. You cannot convert complex numbers into another number type

# Python has a built-in module called random that can be used to make random numbers:
import random

print(random.randrange(1, 10))

# %% [markdown]
# # Strings

# %%
"""
Python is an object-orientated language, and as such it uses classes to define data types, including its primitive types.

Casting in python is therefore done using constructor functions:

int() - constructs an integer number from an integer literal, a float literal (by removing all decimals), or a string literal 
        (providing the string represents a whole number)
float() - constructs a float number from an integer literal, a float literal or a string literal 
          (providing the string represents a float or an integer)
str() - constructs a string from a wide variety of data types, including strings, integer literals and float literals
"""

# You can assign a multiline string to a variable by using three quotes:
a = """This is a multi-line string.
Hello, world.
"""
print(a)  #you can also use single three quotes ''' '''


# Strings in Python are arrays of unicode characters, square brackets can be used to access elements of the string:
print(a[1])

# We can also loop through the characters in a string, with a for loop:
b = "banana"
for x in b:
    print(x)

print(len(b))
# Out:
# This is a multi-line string.
# Hello, world.
#
# h
# b
# a
# n
# a
# n
# a
# 6

# %%
# To check if a certain phrase or character is present in a string, we can use the keyword in:
txt = "The best things in life are free!"
print("free" in txt)

# To check if a certain phrase or character is NOT present in a string, we can use the keyword not in:
print("expensive" not in txt)
# Out:
# True
# True

# %%
""" Slicing strings
"""
# By leaving out the start index, the range will start at the first character:
c = "Hello, World!"
print(c[:5])

# By leaving out the end index, the range will go to the end:
print(c[2:])

# Use negative indexes to start the slice from the end of the string:
print(c[-5:-2])  # not included: "d" in "World!" (position -2)

""" Modify Strings
"""
print(c.upper())
print(c.lower())

# The strip() method removes any whitespace from the beginning or the end:
d = " Hello, World! "
print(d.strip())
print(d.replace("H", "J"))

# The split() method returns a list where the text between the specified separator becomes the list items:
print(d.split(","))
# Out:
# Hello
# llo, World!
# orl
# HELLO, WORLD!
# hello, world!
# Hello, World!
#  Jello, World!
# [' Hello', ' World! ']

# %%
""" Concatenate strings
"""
# Merge variable a with variable b into variable c by using the + operator:
a = "Hello"
b = "World"
c = a + b
print(c)

# To add a space between them, add a " ":
c = a + " " + b
print(c)

""" Format strings
"""
# This will produce an error:
# txt = "My name is John, I am " + age    because we cannot combine strings and numbers like this
# But we can combine strings and numbers by using f-strings or the format() method.

age = 36
txt = f"My name is John, I am {age}"
print(txt)

price = 59
txt1 = f"The price is {price} dollars"
print(txt1)

# A modifier is included by adding a colon : followed by a legal formatting type, like .2f which means fixed point number with 2 decimals:
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)

# A placeholder can contain Python code, like math operations:
txt = f"The price is {20 * 59} dollars"
print(txt)

# %%
""" Escape Characters
"""
# To insert characters that are illegal in a string, use an escape character.
# An escape character is a backslash \ followed by the character you want to insert.
# An example of an illegal character is a double quote inside a string that is surrounded by double quotes:
txt = "We are the so-called \"Vikings\" from the north."
print(txt)

# String methods: https://www.w3schools.com/python/python_strings_methods.asp
# Out:
# We are the so-called "Vikings" from the north.

# %% [markdown]
# # Booleans

# %%
# Almost any value is evaluated to True if it has some sort of content.
# Any string is True, except empty strings.
# Any number is True, except 0.
# Any list, tuple, set, and dictionary are True, except empty ones.
print(bool("abc"))
print(bool(0))
print(bool(["apple", "cherry", "banana"]))
print(bool(None))

# Python also has many built-in functions that return a boolean value, like the isinstance() function, 
# which can be used to determine if an object is of a certain data type:
x = 200
print(isinstance(x, int))
# Out:
# True
# False
# True
# False
# True

# %% [markdown]
# # Python operators

# %%
""" Arithmetic operators
"""
x = 5
y = 2

print(x + y   #addition  
print(x - y)  #subtraction
print(x * y)  #multiplication
print(x/y)    #division
print(x%y)    #modulus: used to find the remainder after dividing one number by another
print(x**y)   #exponentiation
print(x//y)   #floor division: rounds the result down to the nearest whole number

# / - Division (returns a float)
# // - Floor division (returns an integer)

""" Comparison operators
"""
# Python allows you to chain comparison operators

print(1 < x < 10)

print(1 < x and x < 10)

# %%
""" Logical operators
"""
# and: returns True if both statements are true
# or: returns True if one of the statements is true
# not: reverse the result, returns False if the result is true

""" Identity operators
"""
# is: returns True if both variables are the same object
# is not: returns True if both variables are not the same object
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is z)
print(x is y)
print(x == y)

# is - Checks if both variables point to the same object in memory
# == - Checks if the values of both variables are equal
print(x == y) 

""" Membership operators
"""
# in: returns True if a sequence with the specified value is present in the object
# not in: returns True if a sequence with the specified value is not present in the object
fruits = ["apple", "banana", "cherry"]

print("banana" in fruits)
print("orange" in fruits)
print("cherry" not in fruits)

text = "Hello World"

print("H" in text)
print("hello" in text)
print("z" not in text)
# Out:
# True
# False
# True
# True
# True
# False
# False
# True
# False
# True
