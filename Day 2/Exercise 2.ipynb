# %%
maxdistance = 15
temperature = 38.4
greet_ing = "Hello"
isRaining = False

# %%
1st_value = value1
Total$Amount = total_amount
calcNum = calc_num
Data-Entry = data_entry
# Out:
#   Cell In[2], line 1
#     1st_value = value1
#     ^
# SyntaxError: invalid decimal literal

# %%
float(42)
# Out:
# 42.0

# %%
int(3.14159)
# Out:
# 3

# %%
str(99.99)
# Out:
# '99.99'

# %%
float(99.99)
# Out:
# 99.99

# %%
type(maxdistance)
# Out:
# int

# %%
type(temperature)
# Out:
# float

# %%
print(type(greet_ing))
print(type(isRaining))
# Out:
# <class 'str'>
# <class 'bool'>
