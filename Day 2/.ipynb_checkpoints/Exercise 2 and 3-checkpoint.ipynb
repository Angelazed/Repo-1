# %%
a = "This is a 'single quote'"
a
# Out:
# "This is a 'single quote'"

# %%
a2 = 'This is a "double" quote'
a2
# Out:
# 'This is a "double" quote'

# %%
a3 = """ This is a multiple line quote:
third exercise.
"""
a3
# Out:
# ' This is a multiple line quote:\nthird exercise.\n'

# %%
b = "sunny"
print(f"Today is a {b} day")
# Out:
# Today is a sunny day

# %%
slice = a2[:2]+a2[-2:]
slice
# Out:
# 'Thte'

# %%
slice1 = a2[:2].lower()+a2[-2:].upper()
slice1
# Out:
# 'thTE'

# %% [markdown]
# Python operators exercises

# %%
def ex_2(a,b):
    return (a+b, a-b, a*b, a/b, a**b, a%b, a//b)

ex_2(5,7)
# Out:
# (12, -2, 35, 0.7142857142857143, 78125, 5, 0)

# %%
print(5>7)
print(5==9)
print(5>2)
# Out:
# False
# False
# True

# %%
print(not(5>8 and 7==10))
print(8>3 and 2>6)
print(5<2 or 9>2)
print(5<3 and (7<9) or 4>1)
print(5<3 and (7<9) or 4<1)
# Out:
# True
# False
# True
# True
# False
