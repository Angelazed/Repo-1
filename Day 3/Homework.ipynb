# %% [markdown]
# # Python modules

# %%
import os

# %%
entries = os.listdir()

# %%
entries
# Out:
# ['.ipynb_checkpoints',
#  'automobile_prices.csv',
#  'data.csv',
#  'Day 3.ipynb',
#  'Exercises.ipynb',
#  'Homework.ipynb',
#  'houses_to_rent_to_fix.csv',
#  'Libraries.ipynb',
#  'my_data.csv']

# %%
import sys

print(f"Python version: {sys.version}")
# Out:
# Python version: 3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# # Data visualization

# %%
import pandas as pd

# %%
pd1 = pd.read_csv("automobile_prices.csv")
pd1
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN      ferrari       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            3                NaN  alfa-romero       gas        std
# 3            1                NaN  alfa-romero       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo       gas      turbo
# 203         -1               95.0        volvo       gas        std
# 204         -1               95.0        volvo    diesel      turbo
# 205         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
pd1["engine-size"].plot(kind = "line", title = "Automobile engine size", xlabel = "Number of cars", ylabel = "Engine size", color = "gold")
# Out:
# <Axes: title={'center': 'Automobile engine size'}, xlabel='Number of cars', ylabel='Engine size'>
