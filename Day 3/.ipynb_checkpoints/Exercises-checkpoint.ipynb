# %% [markdown]
# # Python functions
# Exercise 1

# %%
def calculate_area(width, height):
    return(width*height)

width = float(input("Please enter width "))
height = float(input("Please enter height "))

total_area = calculate_area(width, height)
print(f"The area is: {total_area}")
# Out:
# Please enter width  2
# Please enter height  7
# The area is: 14.0

# %% [markdown]
# Exercise 2

# %%
my_list = [1,2,3,4,5]
my_list[-1]
# Out:
# 5

# %%
def first_and_last(l):
    return l[0], l[-1]

first_and_last(my_list)
# Out:
# (1, 5)

# %% [markdown]
# Exercise 3

# %% [markdown]
# # Modules and libraries

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2026, 2, 18, 9, 56, 14, 68325)

# %%
#to improve the readability
now = dt.datetime.now()
now.strftime("%d/%m/%Y %H:%M") #we use %d if we want to see the day first, then the month m, the year, the hour, the minutes M
# Out:
# '18/02/2026 09:59'

# %%
from random import randint

# %%
randint(1,10)
# Out:
# 3
